# %%
import pandas as pd
#Create dateframe from CSV
df = pd.read_csv('states.csv')
#Display dataframe
#df

# %%
#Display maximum number of statef columns
pd.set_option('display.max_columns', 51)

# %%
#Display first five rows
df.head()
# Out:
#    fips country state  county  level  lat          locationId  long  \
# 0     2     USA    AK     NaN  state  NaN  iso1:us#iso2:us-ak   NaN
# 1     1     USA    AL     NaN  state  NaN  iso1:us#iso2:us-al   NaN
# 2     5     USA    AR     NaN  state  NaN  iso1:us#iso2:us-ar   NaN
# 3     4     USA    AZ     NaN  state  NaN  iso1:us#iso2:us-az   NaN
# 4     6     USA    CA     NaN  state  NaN  iso1:us#iso2:us-ca   NaN
#
#    population  metrics.testPositivityRatio  \
# 0      731545                     0.031094
# 1     4903185                     0.055615
# 2     3017804                     0.019488
# 3     7278717                     0.039807
# 4    39512223                     0.019207
#
#   metrics.testPositivityRatioDetails.source  metrics.caseDensity  \
# 0                                     other            20.719358
# 1                                     other             8.274505
# 2                                     other             6.158688
# ...

# %%
#Shoe no. of rows and columns
df.shape
# Out:
# (53, 51)

# %%
#
df.describe()

# %%
df.describe().T
# Out:
#                                                count          mean  \
# fips                                            53.0  3.052830e+01
# county                                           0.0           NaN
# lat                                              0.0           NaN
# long                                             0.0           NaN
# population                                      53.0  6.254468e+06
# metrics.testPositivityRatio                     52.0  4.654456e-02
# metrics.caseDensity                             53.0  1.799164e+01
# metrics.contactTracerCapacityRatio              51.0  2.763236e-01
# metrics.infectionRate                           52.0  1.018397e+00
# metrics.infectionRateCI90                       52.0  1.058897e-01
# metrics.icuHeadroomRatio                        52.0  2.094818e-01
# metrics.icuHeadroomDetails.currentIcuCovid      52.0  1.592500e+02
# metrics.icuHeadroomDetails.currentIcuNonCovid   52.0  1.006615e+03
# ...

# %%
df['actuals.cases'].value_counts()
# Out:
# 1013119    1
# 304695     1
# 550068     1
# 44248      1
# 61744      1
# 900271     1
# 83340      1
# 409260     1
# 1020584    1
# 911694     1
# 2747686    1
# 1243171    1
# 164256     1
# 159        1
# 631031     1
# 56190      1
# 330008     1
# 461969     1
# 304143     1
# 209165     1
# 3664012    1
# 350219     1
# 634062     1
# 140550     1
# 687621     1
# 512054     1
# 179897     1
# 191230     1
# 19002      1
# 583933     1
# 365029     1
# 839160     1
# 1032045    1
# 1858162    1
# 50030      1
# 2043501    1
# 307615     1
# 428335     1
# 102671     1
# 104293     1
# 136419     1
# 29626      1
# 437853     1
# 117336     1
# 795088     1
# 516686     1
# 732621     1
# 384815     1
# 303305     1
# 94402      1
# 140991     1
# 616509     1
# 443905     1
# Name: actuals.cases, dtype: int64

# %%
#Display colimns
df.columns
# Out:
# Index(['fips', 'country', 'state', 'county', 'level', 'lat', 'locationId',
#        'long', 'population', 'metrics.testPositivityRatio',
#        'metrics.testPositivityRatioDetails.source', 'metrics.caseDensity',
#        'metrics.contactTracerCapacityRatio', 'metrics.infectionRate',
#        'metrics.infectionRateCI90', 'metrics.icuHeadroomRatio',
#        'metrics.icuHeadroomDetails.currentIcuCovid',
#        'metrics.icuHeadroomDetails.currentIcuCovidMethod',
#        'metrics.icuHeadroomDetails.currentIcuNonCovid',
#        'metrics.icuHeadroomDetails.currentIcuNonCovidMethod',
#        'metrics.icuCapacityRatio', 'riskLevels.overall',
#        'riskLevels.testPositivityRatio', 'riskLevels.caseDensity',
#        'riskLevels.contactTracerCapacityRatio', 'riskLevels.infectionRate',
#        'riskLevels.icuHeadroomRatio', 'riskLevels.icuCapacityRatio',
#        'actuals.cases', 'actuals.deaths', 'actuals.positiveTests',
#        'actuals.negativeTests', 'actuals.contactTracers',
# ...

# %% [markdown]
# # Heading

# %% [markdown]
# # Tittle

# %% [markdown]
# # A dataframe is a two dimensional array (rows and columns).
# In Python this can be explained as
# - Dictionary reps the Dataframe
# - Key is the Series
# - Values are the rows(python list)
# ![image.png](attachment:image.png)

# %%
#Access particular columns(series)
df['state']
# Out:
# 0     AK
# 1     AL
# 2     AR
# 3     AZ
# 4     CA
# 5     CO
# 6     CT
# 7     DC
# 8     DE
# 9     FL
# 10    GA
# 11    HI
# 12    IA
# 13    ID
# 14    IL
# 15    IN
# 16    KS
# 17    KY
# 18    LA
# 19    MA
# 20    MD
# 21    ME
# 22    MI
# 23    MN
# 24    MO
# 25    MP
# 26    MS
# 27    MT
# 28    NC
# 29    ND
# 30    NE
# 31    NH
# 32    NJ
# 33    NM
# 34    NV
# 35    NY
# 36    OH
# 37    OK
# 38    OR
# 39    PA
# 40    PR
# 41    RI
# 42    SC
# 43    SD
# 44    TN
# 45    TX
# 46    UT
# 47    VA
# 48    VT
# 49    WA
# 50    WI
# 51    WV
# 52    WY
# Name: state, dtype: object

# %%
#Access seberal columns - series
sr = df [['state', 'county', 'level','actuals.cases', 'actuals.deaths', 'actuals.positiveTests',
       'actuals.negativeTests']]
#Display filtered dataframe
sr.head()
# Out:
#   state  county  level  actuals.cases  actuals.deaths  actuals.positiveTests  \
# 0    AK     NaN  state          61744             299                 102973
# 1    AL     NaN  state         512054           10526                 506682
# 2    AR     NaN  state         330008            5601                 229711
# 3    AZ     NaN  state         839160           16919                 821402
# 4    CA     NaN  state        3664012           58988                3610393
#
#    actuals.negativeTests
# 0                1908697
# 1                3650461
# 2                2351444
# 3                5851603
# 4               41300952

# %% [markdown]
# ####  **iloc** refers to integer location therefore uses unteger indexes.

# %%
#Access rows of dataframe
df.iloc[19]
# Out:
# fips                                                                                            25
# country                                                                                        USA
# state                                                                                           MA
# county                                                                                         NaN
# level                                                                                        state
# lat                                                                                            NaN
# locationId                                                                      iso1:us#iso2:us-ma
# long                                                                                           NaN
# population                                                                                 6892503
# ...

# %%
#Access rows of filtered dataframe
sr.iloc[19]
# Out:
# state                          MA
# county                        NaN
# level                       state
# actuals.cases              631031
# actuals.deaths              17130
# actuals.positiveTests      708326
# actuals.negativeTests    17680681
# Name: 19, dtype: object

# %%
#Access multiple rows
sr.iloc[6:12]
# Out:
#    state  county  level  actuals.cases  actuals.deaths  actuals.positiveTests  \
# 6     CT     NaN  state         307615            7883                 428797
# 7     DC     NaN  state          44248            1059                  61800
# 8     DE     NaN  state          94402            1552                 109458
# 9     FL     NaN  state        2043501           33246                2568112
# 10    GA     NaN  state        1032045           18381                 788914
# 11    HI     NaN  state          29626             459                  34356
#
#     actuals.negativeTests
# 6                 7188292
# 7                 1555945
# 8                 1660755
# 9                22634372
# 10                6620478
# 11                1175057

# %%
#Access multiple rows
sr.iloc[[3,5,8,14,32]]
# Out:
#    state  county  level  actuals.cases  actuals.deaths  actuals.positiveTests  \
# 3     AZ     NaN  state         839160           16919                 821402
# 5     CO     NaN  state         461969            6166                 444680
# 8     DE     NaN  state          94402            1552                 109458
# 14    IL     NaN  state        1243171           23527                1223943
# 32    NJ     NaN  state         900271           24404                 829203
#
#     actuals.negativeTests
# 3                 5851603
# 5                 6002916
# 8                 1660755
# 14               15012137
# 32               10496625

# %%
#Access specific rows and columns
sr.iloc[[3,5,8,14,32], [0,1,4]]
# Out:
#    state  county  actuals.deaths
# 3     AZ     NaN           16919
# 5     CO     NaN            6166
# 8     DE     NaN            1552
# 14    IL     NaN           23527
# 32    NJ     NaN           24404

# %% [markdown]
# #### For *loc* indexes can be strings

# %%
#Access multiple rows
df.loc[[3,5,8,14,32],['state','actuals.hospitalBeds.capacity','actuals.deaths']]
# Out:
#    state  actuals.hospitalBeds.capacity  actuals.deaths
# 3     AZ                        18286.0           16919
# 5     CO                        13464.0            6166
# 8     DE                         4052.0            1552
# 14    IL                        38143.0           23527
# 32    NJ                        30568.0           24404

# %% [markdown]
# When slicing .loc the last index is inclusive.

# %%
df.loc[6:12, 'actuals.cases': 'actuals.newCases']
# Out:
#     actuals.cases  actuals.deaths  actuals.positiveTests  \
# 6          307615            7883                 428797
# 7           44248            1059                  61800
# 8           94402            1552                 109458
# 9         2043501           33246                2568112
# 10        1032045           18381                 788914
# 11          29626             459                  34356
# 12         350219            5729                 347889
#
#     actuals.negativeTests  actuals.contactTracers  \
# 6                 7188292                     860
# 7                 1555945                     268
# 8                 1660755                     211
# 9                22634372                    2600
# 10                6620478                    1570
# 11                1175057                     300
# 12                2798784                     403
#
#     actuals.hospitalBeds.capacity  actuals.hospitalBeds.currentUsageTotal  \
# ...

# %% [markdown]
# ### Setting indexes

# %%
df = pd.read_csv('states.csv')
#Make 'state' the index
df.set_index('state', inplace= True)
#display
df.head()
# Out:
#        fips country  county  level  lat          locationId  long  population  \
# state
# AK        2     USA     NaN  state  NaN  iso1:us#iso2:us-ak   NaN      731545
# AL        1     USA     NaN  state  NaN  iso1:us#iso2:us-al   NaN     4903185
# AR        5     USA     NaN  state  NaN  iso1:us#iso2:us-ar   NaN     3017804
# AZ        4     USA     NaN  state  NaN  iso1:us#iso2:us-az   NaN     7278717
# CA        6     USA     NaN  state  NaN  iso1:us#iso2:us-ca   NaN    39512223
#
#        metrics.testPositivityRatio metrics.testPositivityRatioDetails.source  \
# state
# AK                        0.031094                                     other
# AL                        0.055615                                     other
# AR                        0.019488                                     other
# AZ                        0.039807                                     other
# CA                        0.019207                                     other
#
# ...

# %%
#Check index
df.index
# Out:
# Index(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI',
#        'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN',
#        'MO', 'MP', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY',
#        'OH', 'OK', 'OR', 'PA', 'PR', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA',
#        'VT', 'WA', 'WI', 'WV', 'WY'],
#       dtype='object', name='state')

# %%
df.loc['NY']
# Out:
# fips                                                                                       36
# country                                                                                   USA
# county                                                                                    NaN
# level                                                                                   state
# lat                                                                                       NaN
# locationId                                                                 iso1:us#iso2:us-ny
# long                                                                                      NaN
# population                                                                           19453561
# metrics.testPositivityRatio                                                         0.0548207
# metrics.testPositivityRatioDetails.source                                               other
# ...

# %%
#Setting the index when loading CSV File
df = pd.read_csv('states.csv', index_col='fips')
df
# Out:
#      country state  county  level  lat          locationId  long  population  \
# fips
# 2        USA    AK     NaN  state  NaN  iso1:us#iso2:us-ak   NaN      731545
# 1        USA    AL     NaN  state  NaN  iso1:us#iso2:us-al   NaN     4903185
# 5        USA    AR     NaN  state  NaN  iso1:us#iso2:us-ar   NaN     3017804
# 4        USA    AZ     NaN  state  NaN  iso1:us#iso2:us-az   NaN     7278717
# 6        USA    CA     NaN  state  NaN  iso1:us#iso2:us-ca   NaN    39512223
# 8        USA    CO     NaN  state  NaN  iso1:us#iso2:us-co   NaN     5758736
# 9        USA    CT     NaN  state  NaN  iso1:us#iso2:us-ct   NaN     3565287
# 11       USA    DC     NaN  state  NaN  iso1:us#iso2:us-dc   NaN      705749
# 10       USA    DE     NaN  state  NaN  iso1:us#iso2:us-de   NaN      973764
# 12       USA    FL     NaN  state  NaN  iso1:us#iso2:us-fl   NaN    21477737
# 13       USA    GA     NaN  state  NaN  iso1:us#iso2:us-ga   NaN    10617423
# ...

# %%
#Reset the index
df.reset_index(inplace=True)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=53, step=1)
